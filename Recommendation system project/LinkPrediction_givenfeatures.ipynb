# %%
import networkx as nx
import numpy as np
import pandas as pd
from stellargraph import StellarGraph, datasets
from stellargraph.data import EdgeSplitter
from sklearn.model_selection import train_test_split
from node2vec import Node2Vec
from gensim.models import KeyedVectors
from sklearn import metrics
from tqdm import tqdm

from tensorflow import keras
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import concatenate

# %%
graph_train_pos_nodes = np.load('data/graph_train_pos_nodes.npy')
graph_train_pos_edges = np.load('data/graph_train_pos_edges.npy')
edge_test = np.load('data/edge_test.npy')
label_test = np.load('data/label_test.npy')
edge_val = np.load('data/edge_val.npy')
label_val = np.load('data/label_val.npy')
edge_train = np.load('data/edge_train.npy')
label_train = np.load('data/label_train.npy')
graph_train_pos = nx.Graph()
graph_train_pos.add_nodes_from(graph_train_pos_nodes)
graph_train_pos.add_edges_from(graph_train_pos_edges)

# %%
edge_test_coef = np.load('data/edge_test_coef.npy')
edge_val_coef = np.load('data/edge_val_coef.npy')
edge_train_coef = np.load('data/edge_train_coef.npy')

# %%
node_embedding = np.load('data/features_preprocessed_128.npy')

def get_edge_embedding(edges, node_embedding, binaryoperator):
    if binaryoperator=='multiplication':
        def binary_operator(u,v):
            return u*v
    elif binaryoperator=='absolute':
        def binary_operator(u,v):
            return np.abs(u-v)
    elif binaryoperator=='average':
        def binary_operator(u,v):
            return (u+v)/2 
    elif binaryoperator=='square difference':
        def binary_operator(u,v):
            return (u-v)**2
        
    edge_embedding = []
    for i in range(len(edges)):
        u = node_embedding[edges[i][0]]
        v = node_embedding[edges[i][1]]
        uv = binary_operator(u,v)
        edge_embedding.append(uv)
    edge_embedding = np.array(edge_embedding)
    return edge_embedding


edge_train_embedding = get_edge_embedding(edge_train, node_embedding, 'multiplication')
edge_val_embedding = get_edge_embedding(edge_val, node_embedding, 'multiplication')
edge_test_embedding = get_edge_embedding(edge_test, node_embedding, 'multiplication')

edge_train_embedding_abs = get_edge_embedding(edge_train, node_embedding, 'absolute')
edge_val_embedding_abs = get_edge_embedding(edge_val, node_embedding, 'absolute')
edge_test_embedding_abs = get_edge_embedding(edge_test, node_embedding, 'absolute')

edge_train_embedding_avg = get_edge_embedding(edge_train, node_embedding, 'average')
edge_val_embedding_avg = get_edge_embedding(edge_val, node_embedding, 'average')
edge_test_embedding_avg = get_edge_embedding(edge_test, node_embedding, 'average')

edge_train_embedding_sqdiff = get_edge_embedding(edge_train, node_embedding, 'square difference')
edge_val_embedding_sqdiff = get_edge_embedding(edge_val, node_embedding, 'square difference')
edge_test_embedding_sqdiff = get_edge_embedding(edge_test, node_embedding, 'square difference')

# %%
def get_edge_ml(edges, node_ml):
    edge_ml = []
    for i in range(len(edges)):
        u = node_ml[edges[i][0]]
        v = node_ml[edges[i][1]]
        uv = np.abs(u-v)
        edge_ml.append(uv)
    edge_ml = np.array(edge_ml)
    return edge_ml

all_ml = pd.read_csv('data/musae_git_target.csv')
node_ml = all_ml['ml_target'].values
edge_train_ml = get_edge_ml(edge_train, node_ml)
edge_val_ml = get_edge_ml(edge_val, node_ml)
edge_test_ml = get_edge_ml(edge_test, node_ml)

# %%
predictions_test = pd.read_csv('data/predictions_test_APPNP_feature.csv', index_col=0)
all_nodes = np.array(range(len(graph_train_pos_nodes)))
nodeclassification_test_node = predictions_test['node_id'].values
nodeclassification_train_node = np.delete(all_nodes, nodeclassification_test_node)

def get_observable_edges(edge, edge_label, observable_node):    
    observable_idx = []
    nonobservable_idx = []
    
    for i in range(len(edge)):
        x = edge[i]
        if x[0] in observable_node and x[1] in observable_node:
            observable_idx.append(i)
        else:
            nonobservable_idx.append(i)

    return observable_idx, nonobservable_idx

observable_edge_test_idx, nonobservable_edge_test_idx = get_observable_edges(edge_test, label_test, nodeclassification_train_node)
observable_edge_val_idx, nonobservable_edge_val_idx = get_observable_edges(edge_val, label_val, nodeclassification_train_node)
observable_edge_train_idx, nonobservable_edge_train_idx = get_observable_edges(edge_train, label_train, nodeclassification_train_node)

# %%
observable_edge_test_coef = edge_test_coef[observable_edge_test_idx]
observable_edge_val_coef = edge_val_coef[observable_edge_val_idx]
observable_edge_train_coef = edge_train_coef[observable_edge_train_idx]

observable_edge_test_embedding = edge_test_embedding[observable_edge_test_idx]
observable_edge_val_embedding = edge_val_embedding[observable_edge_val_idx]
observable_edge_train_embedding = edge_train_embedding[observable_edge_train_idx]

observable_edge_test_embedding_abs = edge_test_embedding_abs[observable_edge_test_idx]
observable_edge_val_embedding_abs = edge_val_embedding_abs[observable_edge_val_idx]
observable_edge_train_embedding_abs = edge_train_embedding_abs[observable_edge_train_idx]

observable_edge_test_embedding_avg = edge_test_embedding_avg[observable_edge_test_idx]
observable_edge_val_embedding_avg = edge_val_embedding_avg[observable_edge_val_idx]
observable_edge_train_embedding_avg = edge_train_embedding_avg[observable_edge_train_idx]

observable_edge_test_embedding_sqdiff = edge_test_embedding_sqdiff[observable_edge_test_idx]
observable_edge_val_embedding_sqdiff = edge_val_embedding_sqdiff[observable_edge_val_idx]
observable_edge_train_embedding_sqdiff = edge_train_embedding_sqdiff[observable_edge_train_idx]

observable_edge_test_ml = edge_test_ml[observable_edge_test_idx]
observable_edge_val_ml = edge_val_ml[observable_edge_val_idx]
observable_edge_train_ml = edge_train_ml[observable_edge_train_idx]

observable_edge_test_label = label_test[observable_edge_test_idx]
observable_edge_val_label = label_val[observable_edge_val_idx]
observable_edge_train_label = label_train[observable_edge_train_idx]

# %%
#train link prediction model
inputA = Input(shape=(6))
inputB = Input(shape=(128))
inputC = Input(shape=(1))

x = Dense(128, activation="relu")(inputA)
x = Dense(64, activation="relu")(x)
x = Dense(32, activation="relu")(x)
x = Dense(16, activation="relu")(x)
x = Dense(4, activation="relu")(x)
x = Dense(1)(x)
x = Model(inputs=inputA, outputs=x)

y = Dense(64, activation="relu")(inputB)
y = Dense(16, activation="relu")(y)
y = Dense(4, activation="relu")(y)
y = Dense(1)(y)
y = Model(inputs=inputB, outputs=y)

z = Dense(1, activation="relu")(inputC)
z = Model(inputs=inputC, outputs=z)

#combine the above models
combined = concatenate([x.output, y.output, z.output])
w = Dense(8, activation="relu")(combined)
w = Dense(4, activation="relu")(w)
w = Dense(1)(w)

model = Model(inputs=[x.input, y.input, z.input], outputs=w)
model.compile('adam', 'mean_squared_error', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          896         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           8256        dense[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 128)]        0
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           2080        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 64)           8256        input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 16)           528         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 16)           1040        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 4)            68          dense_3[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 4)            68          dense_7[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            5           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            5           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            2           input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 3)            0           dense_5[0][0]
#                                                                  dense_9[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 8)            32          concatenate[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 4)            36          dense_11[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1)            5           dense_12[0][0]
# ==================================================================================================
# Total params: 21,277
# Trainable params: 21,277
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit([observable_edge_train_coef, observable_edge_train_embedding, observable_edge_train_ml], observable_edge_train_label, batch_size=512, epochs=40)
model.save('model/link_prediction_mult_givenfeatures.h5')
model.fit([observable_edge_train_coef, observable_edge_train_embedding_abs, observable_edge_train_ml], observable_edge_train_label, batch_size=512, epochs=40)
model.save('model/link_prediction_abs_givenfeatures.h5')
model.fit([observable_edge_train_coef, observable_edge_train_embedding_avg, observable_edge_train_ml], observable_edge_train_label, batch_size=512, epochs=40)
model.save('model/link_prediction_avg_givenfeatures.h5')
model.fit([observable_edge_train_coef, observable_edge_train_embedding_sqdiff, observable_edge_train_ml], observable_edge_train_label, batch_size=512, epochs=40)
model.save('model/link_prediction_sqdiff_givenfeatures.h5')
# Out:
# Epoch 1/40
# 748/748 [==============================] - 5s 3ms/step - loss: 10319.1837 - accuracy: 0.5582
# Epoch 2/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1447 - accuracy: 0.7954
# Epoch 3/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1335 - accuracy: 0.8155:
# Epoch 4/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1269 - accuracy: 0.8253
# Epoch 5/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1237 - accuracy: 0.8298
# Epoch 6/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1204 - accuracy: 0.8337
# Epoch 7/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1184 - accuracy: 0.8358
# Epoch 8/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1162 - accuracy: 0.8395
# Epoch 9/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1134 - accuracy: 0.8433
# Epoch 10/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1123 - accuracy: 0.8453
# Epoch 11/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1113 - accuracy: 0.8467
# Epoch 12/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1102 - accuracy: 0.8486
# Epoch 13/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1092 - accuracy: 0.8499
# Epoch 14/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1081 - accuracy: 0.8513
# Epoch 15/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1076 - accuracy: 0.8523
# Epoch 16/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1073 - accuracy: 0.8530
# Epoch 17/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1063 - accuracy: 0.8542
# Epoch 18/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1066 - accuracy: 0.8546
# Epoch 19/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1053 - accuracy: 0.8558
# Epoch 20/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1056 - accuracy: 0.8552
# Epoch 21/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1043 - accuracy: 0.8576
# Epoch 22/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1038 - accuracy: 0.8584
# Epoch 23/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1039 - accuracy: 0.8579
# Epoch 24/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1039 - accuracy: 0.8588
# Epoch 25/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1030 - accuracy: 0.8599
# Epoch 26/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1026 - accuracy: 0.8598
# Epoch 27/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1022 - accuracy: 0.8605
# Epoch 28/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1016 - accuracy: 0.8613
# Epoch 29/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1016 - accuracy: 0.8620
# Epoch 30/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1014 - accuracy: 0.8616
# Epoch 31/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1011 - accuracy: 0.8622
# Epoch 32/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1015 - accuracy: 0.8626
# Epoch 33/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1004 - accuracy: 0.8637
# Epoch 34/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1004 - accuracy: 0.8641
# Epoch 35/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1001 - accuracy: 0.8648
# Epoch 36/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1004 - accuracy: 0.8636
# Epoch 37/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0993 - accuracy: 0.8655
# Epoch 38/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0997 - accuracy: 0.8645
# Epoch 39/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1000 - accuracy: 0.8644
# Epoch 40/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0990 - accuracy: 0.8657
# Epoch 1/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1574 - accuracy: 0.7760
# Epoch 2/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1313 - accuracy: 0.8171
# Epoch 3/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1247 - accuracy: 0.8275
# Epoch 4/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1202 - accuracy: 0.8341
# Epoch 5/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1166 - accuracy: 0.8392
# Epoch 6/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1143 - accuracy: 0.8418
# Epoch 7/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1126 - accuracy: 0.8447
# Epoch 8/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1110 - accuracy: 0.8472: 0s
# Epoch 9/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1097 - accuracy: 0.8491
# Epoch 10/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1088 - accuracy: 0.8502
# Epoch 11/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1080 - accuracy: 0.8515
# Epoch 12/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1072 - accuracy: 0.8530: 0s - l - ETA: 0s - loss: 0.1072 - accuracy: 0.85
# Epoch 13/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1067 - accuracy: 0.8539
# Epoch 14/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1061 - accuracy: 0.8547
# Epoch 15/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1054 - accuracy: 0.8563
# Epoch 16/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1049 - accuracy: 0.8567
# Epoch 17/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1044 - accuracy: 0.8574: 0s - los
# Epoch 18/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1041 - accuracy: 0.8577: 0s - loss: 0.1043 - accuracy:  - ETA: 0s - loss: 0.1
# Epoch 19/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1038 - accuracy: 0.8583
# Epoch 20/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1034 - accuracy: 0.8593
# Epoch 21/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1030 - accuracy: 0.8594
# Epoch 22/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1028 - accuracy: 0.8599
# Epoch 23/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1024 - accuracy: 0.8604
# Epoch 24/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1021 - accuracy: 0.8611
# Epoch 25/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1019 - accuracy: 0.8615
# Epoch 26/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1015 - accuracy: 0.8620
# Epoch 27/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1012 - accuracy: 0.8624
# Epoch 28/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1010 - accuracy: 0.8626
# Epoch 29/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1008 - accuracy: 0.8628
# Epoch 30/40
# 748/748 [==============================] - 3s 3ms/step - loss: 0.1007 - accuracy: 0.8632: 1s -
# Epoch 31/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1003 - accuracy: 0.8637
# Epoch 32/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1002 - accuracy: 0.8640
# Epoch 33/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1000 - accuracy: 0.8645
# Epoch 34/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0997 - accuracy: 0.8648
# Epoch 35/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0996 - accuracy: 0.8653
# Epoch 36/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0995 - accuracy: 0.8649
# Epoch 37/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0993 - accuracy: 0.8657
# Epoch 38/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0992 - accuracy: 0.8652
# Epoch 39/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0988 - accuracy: 0.8662
# Epoch 40/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0988 - accuracy: 0.8662
# Epoch 1/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1413 - accuracy: 0.7981
# Epoch 2/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1088 - accuracy: 0.8501
# Epoch 3/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0954 - accuracy: 0.8689
# Epoch 4/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0880 - accuracy: 0.8793
# Epoch 5/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0834 - accuracy: 0.8861
# Epoch 6/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0807 - accuracy: 0.8895
# Epoch 7/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0787 - accuracy: 0.8926
# Epoch 8/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0773 - accuracy: 0.8945
# Epoch 9/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0762 - accuracy: 0.8961
# Epoch 10/40
# 748/748 [==============================] - 3s 3ms/step - loss: 0.0754 - accuracy: 0.8971
# Epoch 11/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0746 - accuracy: 0.8984
# Epoch 12/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0740 - accuracy: 0.8992
# Epoch 13/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0736 - accuracy: 0.8999
# Epoch 14/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0730 - accuracy: 0.9006
# Epoch 15/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0726 - accuracy: 0.9012
# Epoch 16/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0724 - accuracy: 0.9017
# Epoch 17/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0721 - accuracy: 0.9023
# Epoch 18/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0717 - accuracy: 0.9026
# Epoch 19/40
# 748/748 [==============================] - 3s 4ms/step - loss: 0.0714 - accuracy: 0.9030: 1s - loss: 0.0708 - accu - ETA: 1s - loss: 0.0712 -  - ETA: 0s - loss: 0
# Epoch 20/40
# 748/748 [==============================] - 3s 3ms/step - loss: 0.0712 - accuracy: 0.9037
# Epoch 21/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0710 - accuracy: 0.9042
# Epoch 22/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0707 - accuracy: 0.9046
# Epoch 23/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0705 - accuracy: 0.9049
# Epoch 24/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.0703 - accuracy: 0.9049
# Epoch 25/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0701 - accuracy: 0.9052: 0s - loss: 0.0701 - ac
# Epoch 26/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0700 - accuracy: 0.9055
# Epoch 27/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0698 - accuracy: 0.9060
# Epoch 28/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0696 - accuracy: 0.9065
# Epoch 29/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.0695 - accuracy: 0.9068
# Epoch 30/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.0693 - accuracy: 0.9068
# Epoch 31/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0692 - accuracy: 0.9072
# Epoch 32/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0691 - accuracy: 0.9075
# Epoch 33/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0689 - accuracy: 0.9080
# Epoch 34/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0687 - accuracy: 0.9079
# Epoch 35/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0687 - accuracy: 0.9079
# Epoch 36/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0685 - accuracy: 0.9083
# Epoch 37/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0684 - accuracy: 0.9085
# Epoch 38/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0684 - accuracy: 0.9085
# Epoch 39/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0682 - accuracy: 0.9092
# Epoch 40/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0681 - accuracy: 0.9096
# Epoch 1/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1430 - accuracy: 0.7988
# Epoch 2/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1250 - accuracy: 0.8253
# Epoch 3/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1200 - accuracy: 0.8325
# Epoch 4/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1161 - accuracy: 0.8383
# Epoch 5/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1131 - accuracy: 0.8426
# Epoch 6/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1109 - accuracy: 0.8464
# Epoch 7/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1092 - accuracy: 0.8490
# Epoch 8/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1074 - accuracy: 0.8519
# Epoch 9/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1059 - accuracy: 0.8539
# Epoch 10/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1049 - accuracy: 0.8553
# Epoch 11/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1042 - accuracy: 0.8565
# Epoch 12/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1032 - accuracy: 0.8578
# Epoch 13/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1026 - accuracy: 0.8589
# Epoch 14/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1020 - accuracy: 0.8599
# Epoch 15/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1015 - accuracy: 0.8608
# Epoch 16/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.1010 - accuracy: 0.8613
# Epoch 17/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1005 - accuracy: 0.8623
# Epoch 18/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.1001 - accuracy: 0.8629
# Epoch 19/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0996 - accuracy: 0.8635
# Epoch 20/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.0993 - accuracy: 0.8642
# Epoch 21/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0990 - accuracy: 0.8645
# Epoch 22/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0987 - accuracy: 0.8653
# Epoch 23/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0983 - accuracy: 0.8659
# Epoch 24/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0982 - accuracy: 0.8663
# Epoch 25/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0979 - accuracy: 0.8665
# Epoch 26/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0976 - accuracy: 0.8670
# Epoch 27/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0973 - accuracy: 0.8675: 0s - loss: 0.0974 - accura
# Epoch 28/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0972 - accuracy: 0.8679
# Epoch 29/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0968 - accuracy: 0.8685
# Epoch 30/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0967 - accuracy: 0.8688
# Epoch 31/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0964 - accuracy: 0.8690
# Epoch 32/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0963 - accuracy: 0.8696
# Epoch 33/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0960 - accuracy: 0.8699
# Epoch 34/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0959 - accuracy: 0.8701
# Epoch 35/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0957 - accuracy: 0.8705
# Epoch 36/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0956 - accuracy: 0.8704
# Epoch 37/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0954 - accuracy: 0.8706
# Epoch 38/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0953 - accuracy: 0.8712
# Epoch 39/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0951 - accuracy: 0.8715: 0s -
# Epoch 40/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0949 - accuracy: 0.8717

# %%
def evaluate(y_test, y_predict):
    accuracy = metrics.accuracy_score(y_test, y_predict)
    precision = metrics.precision_score(y_test, y_predict, average = 'macro')
    recall = metrics.recall_score(y_test, y_predict, average = 'macro')
    f1 = metrics.f1_score(y_test, y_predict, average = 'macro')
    return accuracy, precision, recall, f1

def get_val_result(model, edge_embed):
    prediction = model.predict([observable_edge_test_coef, edge_embed, observable_edge_test_ml])

    y_predict = []
    for i in range(len(prediction)):
        y_predict.append(round(prediction[i][0]))
    accuracy, precision, recall, f1 = evaluate(observable_edge_test_label, y_predict)

    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1: {f1}')

# %%
model = keras.models.load_model('model/link_prediction_mult_givenfeatures.h5')
print('Model with multiplication in edge embedding')
get_val_result(model, observable_edge_test_embedding)
print('')

model = keras.models.load_model('model/link_prediction_abs_givenfeatures.h5')
print('Model with absolute in edge embedding')
get_val_result(model, observable_edge_test_embedding_abs)
print('')

model = keras.models.load_model('model/link_prediction_avg_givenfeatures.h5')
print('Model with average in edge embedding')
get_val_result(model, observable_edge_test_embedding_avg)
print('')

model = keras.models.load_model('model/link_prediction_sqdiff_givenfeatures.h5')
print('Model with sqaure difference in edge embedding')
get_val_result(model, observable_edge_test_embedding_sqdiff)
print('')
# Out:
# Model with multiplication in edge embedding
# Accuracy: 0.8530538795384778
# Precision: 0.8531107945539147
# Recall: 0.8529506668175078
# F1: 0.8530005125126426
#
# Model with absolute in edge embedding
# Accuracy: 0.8568011008785857
# Precision: 0.8568330315355064
# Recall: 0.8568886080895806
# F1: 0.8567981340137754
#
# Model with average in edge embedding
# Accuracy: 0.8959034614163226
# Precision: 0.8959389341173594
# Recall: 0.8959996273273545
# F1: 0.8959014428475955
#
# Model with sqaure difference in edge embedding
# Accuracy: 0.8584524187572774
# Precision: 0.8584720211703797
# Recall: 0.8583770492163076
# F1: 0.8584114991709555

# %%
#final test results

#we test on the edges for nodes that the label for ML developers are hidden 
nonobservable_edge_test_coef = edge_test_coef[nonobservable_edge_test_idx]
nonobservable_edge_test_embedding_avg = edge_test_embedding_avg[nonobservable_edge_test_idx]
nonobservable_edge_test_label = label_test[nonobservable_edge_test_idx]
model = keras.models.load_model('model/link_prediction_avg_givenfeatures.h5')

#get results from the node classification model
output_ml = predictions_test['predicted_label'].values
ml = pd.read_csv('data/musae_git_target.csv')
ml_target = ml['ml_target'].values
nonobservable_edge_test = edge_test[nonobservable_edge_test_idx]

#combine the output results from the node classification model
nonobservable_edge_test_ml = []
for x in nonobservable_edge_test:   
    if x[0] in nodeclassification_test_node:
        idx = np.where(nodeclassification_test_node==x[0])
        u = output_ml[idx]
    else:
        u = ml_target[x[0]]       
        
    if x[1] in nodeclassification_test_node:
        idx = np.where(nodeclassification_test_node==x[1])
        v = output_ml[idx]   
    else:
        v = ml_target[x[1]]
       
    nonobservable_edge_test_ml.append(np.abs(u-v))    
nonobservable_edge_test_ml=np.array(nonobservable_edge_test_ml)


#test the link prediction model
prediction = model.predict([nonobservable_edge_test_coef, nonobservable_edge_test_embedding_avg, nonobservable_edge_test_ml])
y_predict = []
for i in range(len(prediction)):
    y_predict.append(round(prediction[i][0]))
accuracy, precision, recall, f1 = evaluate(nonobservable_edge_test_label, y_predict)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1: {f1}')
# Out:
# Accuracy: 0.8909607193563653
# Precision: 0.8912452682948799
# Recall: 0.8898505793948265
# F1: 0.8904069564525843

# %%
#Model not using the node label ML developer
inputA = Input(shape=(6))
inputB = Input(shape=(128))

x = Dense(128, activation="relu")(inputA)
x = Dense(64, activation="relu")(x)
x = Dense(32, activation="relu")(x)
x = Dense(16, activation="relu")(x)
x = Dense(4, activation="relu")(x)
x = Dense(1)(x)
x = Model(inputs=inputA, outputs=x)

y = Dense(64, activation="relu")(inputB)
y = Dense(16, activation="relu")(y)
y = Dense(4, activation="relu")(y)
y = Dense(1)(y)
y = Model(inputs=inputB, outputs=y)


#combine the above models
combined = concatenate([x.output, y.output])
w = Dense(8, activation="relu")(combined)
w = Dense(4, activation="relu")(w)
w = Dense(1)(w)

model = Model(inputs=[x.input, y.input], outputs=w)
model.compile('adam', 'mean_squared_error', metrics=['accuracy'])
#model.summary()

#train and save model
model.fit([observable_edge_train_coef, observable_edge_train_embedding_avg], observable_edge_train_label, batch_size=512, epochs=40)
model.save('model/link_prediction_avg_noml_givenfeatures.h5')
# Out:
# Epoch 1/40
# 748/748 [==============================] - 3s 3ms/step - loss: 0.2836 - accuracy: 0.6536
# Epoch 2/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.0920 - accuracy: 0.8742
# Epoch 3/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0826 - accuracy: 0.8879
# Epoch 4/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.0784 - accuracy: 0.8939
# Epoch 5/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0767 - accuracy: 0.8956
# Epoch 6/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.0752 - accuracy: 0.8980
# Epoch 7/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0742 - accuracy: 0.8991
# Epoch 8/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0723 - accuracy: 0.9022
# Epoch 9/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0727 - accuracy: 0.9015
# Epoch 10/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0713 - accuracy: 0.9036
# Epoch 11/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0709 - accuracy: 0.9043
# Epoch 12/40
# 748/748 [==============================] - 2s 2ms/step - loss: 0.0701 - accuracy: 0.9052
# Epoch 13/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0701 - accuracy: 0.9050
# Epoch 14/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0699 - accuracy: 0.9050
# Epoch 15/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0689 - accuracy: 0.9071
# Epoch 16/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0691 - accuracy: 0.9064
# Epoch 17/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0691 - accuracy: 0.9067
# Epoch 18/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0678 - accuracy: 0.9088
# Epoch 19/40
# 748/748 [==============================] - 3s 3ms/step - loss: 0.0678 - accuracy: 0.9085: 0s - loss: 0.0677 -
# Epoch 20/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0675 - accuracy: 0.9091
# Epoch 21/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0676 - accuracy: 0.9088
# Epoch 22/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0673 - accuracy: 0.9091
# Epoch 23/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0674 - accuracy: 0.9092
# Epoch 24/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0670 - accuracy: 0.9098
# Epoch 25/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0668 - accuracy: 0.9106
# Epoch 26/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0666 - accuracy: 0.9113
# Epoch 27/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0667 - accuracy: 0.9100
# Epoch 28/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0660 - accuracy: 0.9111
# Epoch 29/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0663 - accuracy: 0.9112
# Epoch 30/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0655 - accuracy: 0.9121
# Epoch 31/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0659 - accuracy: 0.9115
# Epoch 32/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0658 - accuracy: 0.9117
# Epoch 33/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0662 - accuracy: 0.9117
# Epoch 34/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0654 - accuracy: 0.9128
# Epoch 35/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0653 - accuracy: 0.9126
# Epoch 36/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0652 - accuracy: 0.9126
# Epoch 37/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0652 - accuracy: 0.9133
# Epoch 38/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0655 - accuracy: 0.9127
# Epoch 39/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0654 - accuracy: 0.9127
# Epoch 40/40
# 748/748 [==============================] - 2s 3ms/step - loss: 0.0648 - accuracy: 0.9135

# %%
model = keras.models.load_model('model/link_prediction_avg_noml_givenfeatures.h5')
print('Model without ML label and with average in edge embedding')
print('')
prediction = model.predict([nonobservable_edge_test_coef,nonobservable_edge_test_embedding_avg])

y_predict = []
for i in range(len(prediction)):
    y_predict.append(round(prediction[i][0]))
accuracy, precision, recall, f1 = evaluate(nonobservable_edge_test_label, y_predict)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1: {f1}')
# Out:
# Model without ML label and with average in edge embedding
#
# Accuracy: 0.8872692853762423
# Precision: 0.8878934975059478
# Recall: 0.8858737576331359
# F1: 0.8866191848068862
